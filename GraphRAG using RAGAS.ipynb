# %%
import pandas as pd
import random
from datetime import datetime, timedelta

# Configuration
num_records = 1000
start_date = datetime(2024, 1, 1)
end_date = datetime(2024, 12, 31)

hcp_names = ["Dr. A", "Dr. B", "Dr. C", "Dr. D", "Dr. E", "Dr. F", "Dr. G", "Dr. H", "Dr. I", "Dr. J"]
doctor_names = ["MSL X", "MSL Y", "MSL Z", "MSL P", "MSL Q", "MSL R"]
hcp_specialties = ["Oncologist", "Pulmonologist", "Thoracic Surgeon", "Radiologist", "Pathologist"]

custom_sentiment_distribution = {
    "Q1": ["Negative"] * 70 + ["Neutral"] * 20 + ["Positive"] * 10,
    "Q2": ["Negative"] * 60 + ["Neutral"] * 25 + ["Positive"] * 15,
    "Q3": ["Negative"] * 20 + ["Neutral"] * 30 + ["Positive"] * 50,
    "Q4": ["Negative"] *10 + ["Neutral"] * 15 + ["Positive"] * 75,
}


# custom_sentiment_distribution = {
#     "Q1": ["Negative"] * 70 + ["Neutral"] * 20 + ["Positive"] * 10,
#     "Q2": ["Negative"] * 60 + ["Neutral"] * 25 + ["Positive"] * 15,
#     "Q3": ["Negative"] * 50 + ["Neutral"] * 30 + ["Positive"] * 20,
#     "Q4": ["Negative"] * 30 + ["Neutral"] * 30 + ["Positive"] * 40,
# }

negative_templates = [
    "{} expressed hesitation about switching patients to 2L treatment due to severe toxicities experienced during 1L therapy.",
    "{} mentioned NSCLC patients on chemotherapy experiencing issues like neutropenia, anemia, GI toxicity, and pneumonitis, but remaining on 1L therapy too long.",
    "{} mentioned NSCLC patients on immunotherapy experiencing issues like neutropenia, anemia, GI toxicity, and pneumonitis, but remaining on 1L therapy too long.",
    "{} raised concerns about unclear sequencing strategies, delaying necessary transitions to 2L.",
    "{} noted lack of confidence in 2L treatment options due to limited real-world evidence in the community.",
    "{} reported that many patients remain on 1L therapy longer than necessary due to limited options in 2L treatment.",
    "{} indicated hesitation in moving patients to 2L therapy because of adverse effects experienced during 1L treatment.",
    "{} reported that they are reluctant to switch to 2L therapy due to lack of clinical understanding and experience.",
    "{} indicated an increase in patient hospitalization and hence reduced quality of life."
]

positive_templates = [
    "{} shared positive experiences with new clinical trials focusing on safety profiles enrolling more patients.",
    "{} noted a significant improvement in sentiment towards upcoming 2L options due to emerging clinical evidence.",
    "{} mentioned ongoing discussions focusing on sequencing strategies and toxicity management showing promising results.",
    "{} expressed interest in new 2L options demonstrating better safety and tolerability for patients.",
    "{} highlighted progress in trials aimed at reducing toxicities experienced during earlier therapies.",
    "{} reported growing confidence in switching patients to 2L treatment due to improved data on safety profiles.",
    "{} noted increasing patient enrollments in clinical trials addressing issues related to severe toxicities."
]

neutral_templates = [
    "{} discussed current treatment strategies for NSCLC patients facing severe toxicities.",
    "{} reviewed data on treatment discontinuation patterns and patient outcomes in NSCLC.",
    "{} raised concerns about patients discontinuing therapy without transitioning to better-tolerated 2L options.",
    "{} provided general feedback on managing toxicities like neutropenia and fatigue in NSCLC patients.",
    "{} highlighted clinical challenges associated with sequencing strategies in NSCLC treatment.",
    "{} indicated ongoing debates around when to transition patients from 1L to 2L therapy.",
    "{} discussed monitoring patients with severe toxicities during 1L treatment to optimize outcomes."
]

unique_custom_records = []
for _ in range(num_records):
    random_date = start_date + timedelta(days=random.randint(0, (end_date - start_date).days))
    quarter = f"Q{((random_date.month - 1) // 3) + 1}"
    sentiment = random.choice(custom_sentiment_distribution[quarter])


    hcp_name = random.choice(hcp_names)
    hcp_specialty = random.choice(hcp_specialties)
    msl_name = random.choice(doctor_names)

    if sentiment == "Negative":
        note = random.choice(negative_templates).format(hcp_name)
    elif sentiment == "Positive":
        note = random.choice(positive_templates).format(hcp_name)
    else:
        note = random.choice(neutral_templates).format(hcp_name)

    note += f" ({random.choice(['Discussed during recent meeting.', 'Follow-up planned.', 'Awaiting more evidence.'])})"

    unique_custom_records.append({
        "Date": random_date.strftime("%Y-%m-%d"),
        "MSL Note": note,
        "Therapy Area": "Non-small cell lung cancer (NSCLC)",
        "Sentiment": sentiment,
        "HCP Name": hcp_name,
        "HCP Specialty": hcp_specialty,
        "MSL Name": msl_name,
        "Region": random.choice(["North America", "Europe", "Asia", "South America"])
    })

# Enhancing variation by adding more randomness and diversity to the notes
additional_phrases = [
    "This remains a major concern among oncologists.",
    "The current situation is far from ideal.",
    "This issue needs more attention from the medical community.",
    "Oncologists are actively looking for better options.",
    "The lack of real-world evidence is problematic.",
    "There is a need for clearer treatment guidelines.",
    "Newer approaches are being considered by experts.",
    "Clinical data is awaited to support better decisions.",
    "Efforts are ongoing to improve patient outcomes.",
    "The safety profile of new therapies is a key discussion point."
]

# Updating existing notes by randomly appending additional phrases for uniqueness
for record in unique_custom_records:
    if random.random() < 0.7:  # 70% chance of adding an additional phrase for uniqueness
        record["MSL Note"] += " " + random.choice(additional_phrases)

# Creating the updated DataFrame
df_unique_updated = pd.DataFrame(unique_custom_records)

df_unique_updated["Date"] = pd.to_datetime(df_unique_updated["Date"])

# Checking if the number of unique MSL notes is now 1000
num_unique_notes_updated = df_unique_updated["MSL Note"].nunique()
print("Total unique notes: ",num_unique_notes_updated)
# Out:
# Total unique notes:  911

# %%
import pandas as pd
import uuid
import os

# Define the directory where you want to store the text files.
output_directory = 'input'

# Check if the directory exists, if not, create it
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Loop through each row of the dataframe
for index, row in df_unique_updated.iterrows():
    msl_note = row['MSL Note']

    # Generate a unique file name using uuid
    unique_filename = f"MSL_Note_{uuid.uuid4().hex}.txt"

    # Define the full path for the text file
    file_path = os.path.join(output_directory, unique_filename)

    # Write the MSL Mote to a text file
    with open(file_path, 'w') as file:
        file.write(msl_note)

    print(f" File '{file_path}' created successfully")
# Out:
#  File 'input/MSL_Note_fb453856a8994904a690ccf6f018901e.txt' created successfully
#  File 'input/MSL_Note_041ac886a2da470b93f652e753102e27.txt' created successfully
#  File 'input/MSL_Note_bfdb23fb2573401bbedad4d61c048062.txt' created successfully
#  File 'input/MSL_Note_98973de1bf9f4d99aab39b27416d0850.txt' created successfully
#  File 'input/MSL_Note_0ece0f2eab7945f592270b3e3e215a38.txt' created successfully
#  File 'input/MSL_Note_cc0db9f0cdad4fb7a2f8a4ad7aec79fc.txt' created successfully
#  File 'input/MSL_Note_6c35d3b6f695438a8c1ba2d27c766075.txt' created successfully
#  File 'input/MSL_Note_50dab4df3c5147a6994957b3ff6b67bd.txt' created successfully
#  File 'input/MSL_Note_27014b8f470c4f8abe06d391dc049256.txt' created successfully
#  File 'input/MSL_Note_9c222d92e88f490ca38b8e11f9d34cd0.txt' created successfully
#  File 'input/MSL_Note_698f151a4de34f7588f0fb43f76ddcdc.txt' created successfully
#  File 'input/MSL_Note_78b03e643054430cbf14737a52a736d6.txt' created successfully
#  File 'input/MSL_Note_e55413ce4917418dbc8ba459c93371fc.txt' created successfully
#  File 'input/MSL_Note_20ba0248c6a24db4aae3b72832167ef5.txt' created successfully
#  File 'input/MSL_Note_e1909567921541ae99c60db7ff9d45eb.txt' created successfully
#  File 'input/MSL_Note_ec9f74099a2a42ca8bcacc62288a2dd7.txt' created successfully
#  File 'input/MSL_Note_a03d414f006a4373adf67e9c7dcd93c5.txt' created successfully
#  File 'input/MSL_Note_f37868cd9a5f4ccbae5ddd826293c7b2.txt' created successfully
#  File 'input/MSL_Note_fb3b511462744e53b3ed6bbe8f483fc3.txt' created successfully
#  File 'input/MSL_Note_1e3606cabb7649ceafaff697ab2de2ca.txt' created successfully
#  File 'input/MSL_Note_bd8898fb899942519c6d5274305a30f4.txt' created successfully
#  File 'input/MSL_Note_875a30865eba48dabe46172a8e68cacf.txt' created successfully
#  File 'input/MSL_Note_e1aeb8b134644a1da0d57cfd70271768.txt' created successfully
#  File 'input/MSL_Note_98fefedec23e43b68b53003b58daee71.txt' created successfully
#  File 'input/MSL_Note_ee9e942c4ce0429fad60acf68cb76715.txt' created successfully
#  File 'input/MSL_Note_9b042e43467049d6a28012fbc51173c7.txt' created successfully
#  File 'input/MSL_Note_b12a79fd2e7f4e7fa429ae581c7a28b7.txt' created successfully
#  File 'input/MSL_Note_03186f8ea0eb4d15bc5754f6d837095a.txt' created successfully
#  File 'input/MSL_Note_f6a7c07c89884fc4ace88279faa679cc.txt' created successfully
#  File 'input/MSL_Note_bce03479ea174c51a73105a50675cf94.txt' created successfully
#  File 'input/MSL_Note_9f81d51ae72e4792b51557d943f25c90.txt' created successfully
#  File 'input/MSL_Note_47244ffb3fe54049821640ab3d8cc14f.txt' created successfully
#  File 'input/MSL_Note_49a336033e42484f8c646e0e9daba1aa.txt' created successfully
#  File 'input/MSL_Note_3c8c14a372a0417398e6e4f6cf68795d.txt' created successfully
#  File 'input/MSL_Note_53f3784d8e4844a28ac110b0f6d9d9b4.txt' created successfully
#  File 'input/MSL_Note_6c3becf2ea8b42c1b899b39257b35a86.txt' created successfully
#  File 'input/MSL_Note_c86cccff8a4e4c39a881af31a3ec1206.txt' created successfully
#  File 'input/MSL_Note_166fd7302b16445b91a79bbfab74d0d1.txt' created successfully
#  File 'input/MSL_Note_9ed2a2b32b3a4bc68fe2da8f9e3f275e.txt' created successfully
#  File 'input/MSL_Note_232182a8a33c4d5fbfc7a536e48489c6.txt' created successfully
#  File 'input/MSL_Note_c1ab71c38da44fada1f26ce07d276534.txt' created successfully
#  File 'input/MSL_Note_c1dcfc765ec04ab09de631eb6446605c.txt' created successfully
#  File 'input/MSL_Note_988840ef24f14d83993cd4646b0c2414.txt' created successfully
#  File 'input/MSL_Note_5a0943a5a005435fb0127f44f2dc64f5.txt' created successfully
#  File 'input/MSL_Note_42c3cabe44f347d28dc646ca28ba57b1.txt' created successfully
#  File 'input/MSL_Note_6e64d1bd2da44db2926f006a7edb996d.txt' created successfully
#  File 'input/MSL_Note_c8ff0b3620a5477f89ce2f9bd816b292.txt' created successfully
#  File 'input/MSL_Note_767db328ada149ceaa2a505027daa765.txt' created successfully
#  File 'input/MSL_Note_c77c9bbdb66b4576905e4516dbf8caa1.txt' created successfully
#  File 'input/MSL_Note_6a86a6276ada42e9b4f620753317cd51.txt' created successfully
#  File 'input/MSL_Note_65bc66f646a6462a853ebc42db39a361.txt' created successfully
#  File 'input/MSL_Note_a1cc2743f6b54a698f48094d6a73b08b.txt' created successfully
#  File 'input/MSL_Note_74f36cbd71b044c3bc34bca0c9a5e7d9.txt' created successfully
#  File 'input/MSL_Note_cfaf8546390e4d31816b48c7a808dc81.txt' created successfully
#  File 'input/MSL_Note_5df6e4864f754edbaed4621b4968256e.txt' created successfully
#  File 'input/MSL_Note_8282a5959c084df68af11ca663585837.txt' created successfully
#  File 'input/MSL_Note_ec404f2b4175419d82a14d61d6f4a5ff.txt' created successfully
#  File 'input/MSL_Note_c5c4606516824879b7150c952bcd1840.txt' created successfully
#  File 'input/MSL_Note_489037b3ebdd4605a4dd7af5116c1ada.txt' created successfully
#  File 'input/MSL_Note_8876eab349824fe283fa24d4cea5433a.txt' created successfully
#  File 'input/MSL_Note_3e0cb98668af4c7e8a470ea6ce6109dd.txt' created successfully
#  File 'input/MSL_Note_72f8345d93ae49f880b437dbb1da06fe.txt' created successfully
#  File 'input/MSL_Note_6909d85b6fef4bfbbce574b4515b5d26.txt' created successfully
#  File 'input/MSL_Note_42bc3571f2ea48a392b1dc724afac18c.txt' created successfully
#  File 'input/MSL_Note_883192860ffa41cf85780f85d74eeb34.txt' created successfully
#  File 'input/MSL_Note_8526b6acc35b49caafd85f5188569af5.txt' created successfully
#  File 'input/MSL_Note_0e80b41720e846e6b0772a597b85185b.txt' created successfully
#  File 'input/MSL_Note_6fb14d49fdd0402ea02905ed6eadfc9f.txt' created successfully
#  File 'input/MSL_Note_a93aad2d3e474cf5bb9afcac09a95762.txt' created successfully
#  File 'input/MSL_Note_7d42a3f6736e4ffd97d91d5efcd03b0b.txt' created successfully
#  File 'input/MSL_Note_a1cf8a0d1d884b41ae683f23248f7f8f.txt' created successfully
#  File 'input/MSL_Note_e67e5ffe62fd41338567224248ae7813.txt' created successfully
#  File 'input/MSL_Note_3f9f0c8bd7854124afd10af2a6bddba2.txt' created successfully
#  File 'input/MSL_Note_8b38643eb5734bc6b5dae9409aba0e9b.txt' created successfully
#  File 'input/MSL_Note_cf7bb2c792674123bdbab7ac8de2cdb4.txt' created successfully
#  File 'input/MSL_Note_8b988db4409a478c88a1aa9e17435056.txt' created successfully
#  File 'input/MSL_Note_ab67049e5edb432abdc2e9f93628b7c6.txt' created successfully
#  File 'input/MSL_Note_c6e6582ed36c407b83b9da523eeefb1e.txt' created successfully
#  File 'input/MSL_Note_a9c3c8f78f244f67adbbb2b7f7bc7b2a.txt' created successfully
#  File 'input/MSL_Note_48b135997f1b423e8da5a370fff67e25.txt' created successfully
#  File 'input/MSL_Note_9b53b51a54594c169e9f87bc9aaa2af3.txt' created successfully
#  File 'input/MSL_Note_991a51ae7bf34bf0a1496dee94240282.txt' created successfully
#  File 'input/MSL_Note_3eb480d674df4400a0e6d64f220375d6.txt' created successfully
#  File 'input/MSL_Note_e12cd4558ffd4aa6a2d8740cac06a50a.txt' created successfully
#  File 'input/MSL_Note_fb2270062b1141ceae7727cba12329ea.txt' created successfully
#  File 'input/MSL_Note_b973fd58c1e547269c0e0c8215fc960a.txt' created successfully
#  File 'input/MSL_Note_e995c8814a3b4c40a6fa13d05822ec81.txt' created successfully
#  File 'input/MSL_Note_828c87761248446e90f4e8a7b3b720ca.txt' created successfully
#  File 'input/MSL_Note_128860f4243d4cf0b6d8ee9c117acc3d.txt' created successfully
#  File 'input/MSL_Note_595a2ed84956466282cfb0cb5bbb78c6.txt' created successfully
#  File 'input/MSL_Note_cfa444e0525544e8aa2a0ad1df5d87f6.txt' created successfully
#  File 'input/MSL_Note_f96a08cfc4454b659ffc084a10985f05.txt' created successfully
#  File 'input/MSL_Note_74187dd3cd4d4814b832b155dff01b55.txt' created successfully
#  File 'input/MSL_Note_67a2cbd4066646ce8c8c34da820e96a7.txt' created successfully
#  File 'input/MSL_Note_d753349737f3423bb4c0a34212500d5f.txt' created successfully
#  File 'input/MSL_Note_a65d72297abc421191c4c676129f99e4.txt' created successfully
#  File 'input/MSL_Note_0945547671aa475f849d6f100fd01e60.txt' created successfully
#  File 'input/MSL_Note_31043ee4582f473a8ab447b48de5c668.txt' created successfully
#  File 'input/MSL_Note_60e051fe895545e487506eb2dabc334a.txt' created successfully
#  File 'input/MSL_Note_c0af2ef0ea7e4ecfab3afa2e8d43ce63.txt' created successfully
#  File 'input/MSL_Note_bd6915abd00140d58794ce4f763d1a5f.txt' created successfully
#  File 'input/MSL_Note_ca850781e85d4d1da872f0cbbc1dd3d0.txt' created successfully
#  File 'input/MSL_Note_c3c7c550bdfc4f33a4461efa075580f2.txt' created successfully
#  File 'input/MSL_Note_94060ce75dad4e5fb5d0e78e72cd4b9e.txt' created successfully
#  File 'input/MSL_Note_5b66cade747c4f9aada00b06c1f6c089.txt' created successfully
#  File 'input/MSL_Note_69f1a8c730f2425ebf2a00f58d5e6cc4.txt' created successfully
#  File 'input/MSL_Note_6c9a4f7bb5ba4b0cb159bc27944d1a16.txt' created successfully
#  File 'input/MSL_Note_506ad7e3b69b4f77bd83eca8e4a9461b.txt' created successfully
#  File 'input/MSL_Note_dbb28b00f00a43faae063c7f8d2c6306.txt' created successfully
#  File 'input/MSL_Note_4ebc2d6be7d84557ae6bbc39c8784c56.txt' created successfully
#  File 'input/MSL_Note_06f1c693490e42c79630e49ec7def66e.txt' created successfully
#  File 'input/MSL_Note_29d0ac1d64404ff79a220b05af603645.txt' created successfully
#  File 'input/MSL_Note_8b8842037fe943709e2678aac7bf7bd1.txt' created successfully
#  File 'input/MSL_Note_d3445fd37cb74b0bbc5650739d6ccb33.txt' created successfully
#  File 'input/MSL_Note_de0c0f0ca0924aee996fafa824c20371.txt' created successfully
#  File 'input/MSL_Note_98d1f60ac07b4d13a835e04262bcfc7f.txt' created successfully
#  File 'input/MSL_Note_cf996885794a4105b930d5f71ce5c5bb.txt' created successfully
#  File 'input/MSL_Note_7771b7b423f248d2a587f61fdedd9cb8.txt' created successfully
#  File 'input/MSL_Note_10728b8c379040ac95415ee69d2baa4b.txt' created successfully
#  File 'input/MSL_Note_1ab0f92ab55e4f4dbc86732b1249afdc.txt' created successfully
#  File 'input/MSL_Note_96407df0acc04ecc9b77935979e11e6f.txt' created successfully
#  File 'input/MSL_Note_83c32029db874404af652c18009ce3cd.txt' created successfully
#  File 'input/MSL_Note_7e65f9d6fa2343af810347ce797cac2e.txt' created successfully
#  File 'input/MSL_Note_d7cb40bd84cf4897ad850e0d6915994b.txt' created successfully
#  File 'input/MSL_Note_f1d0766b3aed4797ad780b80e6eac0a6.txt' created successfully
#  File 'input/MSL_Note_b8d3229aa7264fe79acbf5ac002ccf9f.txt' created successfully
#  File 'input/MSL_Note_553b7d5375c44e559e6d4bbcc71e0fba.txt' created successfully
#  File 'input/MSL_Note_480a411b8a3e47f9a1febc3d0aba03e0.txt' created successfully
#  File 'input/MSL_Note_1f321ac75b634f0e9ec2f97d50ef65f8.txt' created successfully
#  File 'input/MSL_Note_6bb74d3455e846479f4273725092a2f5.txt' created successfully
#  File 'input/MSL_Note_3afc5aa0a95540c6ab1b002a8f79c48e.txt' created successfully
#  File 'input/MSL_Note_f71de971749f407fac815f95825bafea.txt' created successfully
#  File 'input/MSL_Note_836f1f1ec21a44f9bded1e2d1ada83d3.txt' created successfully
#  File 'input/MSL_Note_33906a57afc84539a323c080d43d5958.txt' created successfully
#  File 'input/MSL_Note_03daeefa14584520b84d35b611ced5c6.txt' created successfully
#  File 'input/MSL_Note_803c2da70cc34773afc0bc14e25687bf.txt' created successfully
#  File 'input/MSL_Note_d06b7018828d4a38b6dfbb3da03bb7fc.txt' created successfully
#  File 'input/MSL_Note_2f8b27a254834efcb71ae0fa78fc75df.txt' created successfully
#  File 'input/MSL_Note_8f9d0c3db49b4213b7a8ceb6843253a4.txt' created successfully
#  File 'input/MSL_Note_e0982a083b814d8888b1b1fd38dce655.txt' created successfully
#  File 'input/MSL_Note_ea78d75fd0da4f8cb0cd956a4db82a48.txt' created successfully
#  File 'input/MSL_Note_1861d2d3c9a24516a644a785121f91fb.txt' created successfully
#  File 'input/MSL_Note_2d60db43a796456fb29f061b82ec3dbb.txt' created successfully
#  File 'input/MSL_Note_dd221a2771ec442aa0ba5e466bf42226.txt' created successfully
#  File 'input/MSL_Note_863013764d44437f9fa6685988399327.txt' created successfully
#  File 'input/MSL_Note_c2c184552cce4688bd43636143a1239e.txt' created successfully
#  File 'input/MSL_Note_1c77f709118941be97fcdd7a7fa9fea3.txt' created successfully
#  File 'input/MSL_Note_66ccf9b6b1654da1b2475f409bb37da3.txt' created successfully
#  File 'input/MSL_Note_b81ab4e00ac646c6ba82d6ffbfab93a2.txt' created successfully
#  File 'input/MSL_Note_211dfbb5f79c49cabf1b324a04c39e64.txt' created successfully
#  File 'input/MSL_Note_267ea7c461954bc39e0e80c74984a26c.txt' created successfully
#  File 'input/MSL_Note_9c83793ec111400f8fc2056b78b79fce.txt' created successfully
#  File 'input/MSL_Note_6f17526720aa41d8ab581da747042755.txt' created successfully
#  File 'input/MSL_Note_64243379807841a59130dab1bf78beeb.txt' created successfully
#  File 'input/MSL_Note_db84e195ecf84b70a61109ffb583ddb5.txt' created successfully
#  File 'input/MSL_Note_ec99f8b2b8194de7b59ef9202f22dfb2.txt' created successfully
#  File 'input/MSL_Note_b5f608c3ac4e4b47b0a4d9ec0958fbbe.txt' created successfully
#  File 'input/MSL_Note_6ebc478297a04335af16f394f1f21de3.txt' created successfully
#  File 'input/MSL_Note_85f867fce6734311a050c25108e1fa09.txt' created successfully
#  File 'input/MSL_Note_44654281b8ed4992be15acc0475f6860.txt' created successfully
#  File 'input/MSL_Note_a66a1963c7f8462e82d1b08b467248c9.txt' created successfully
#  File 'input/MSL_Note_82b9ccd3cf674a7bba89ebb454f088c5.txt' created successfully
#  File 'input/MSL_Note_550713e4a327493b9884f7ddae78fb07.txt' created successfully
#  File 'input/MSL_Note_c4e89ef524c74b85ad3780f2de3d49d5.txt' created successfully
#  File 'input/MSL_Note_9a288c3aacbd4772b7cbdda61f35d437.txt' created successfully
#  File 'input/MSL_Note_3057d3fb3cb64f849c82d0fbeb8d4233.txt' created successfully
#  File 'input/MSL_Note_1bf1b49c47144a27855a2fcfae48736a.txt' created successfully
#  File 'input/MSL_Note_3134697bf954497bb809b7a8899511d0.txt' created successfully
#  File 'input/MSL_Note_3d45da06dbc349fb8177bfec1d236c55.txt' created successfully
#  File 'input/MSL_Note_cb20a1bf6bfd43cb8c9037a34f7eec5a.txt' created successfully
#  File 'input/MSL_Note_0479b9219fc5410dbb9a8cdde269349e.txt' created successfully
#  File 'input/MSL_Note_bbfc57013a4f4e55a875a898f9888ca0.txt' created successfully
#  File 'input/MSL_Note_dba7d419ecb54fbeb0e5e89849a7ddbc.txt' created successfully
#  File 'input/MSL_Note_4e7161bbfeac4e2b92a7f026cc26322f.txt' created successfully
#  File 'input/MSL_Note_13dff1e8caff4ad7ada71d5d8f5faf01.txt' created successfully
#  File 'input/MSL_Note_bfaacd5cc8224a3cb9e610de550c0c3b.txt' created successfully
#  File 'input/MSL_Note_a46c48f067c74538ae9a512ce6e97132.txt' created successfully
#  File 'input/MSL_Note_310280bb79594af3ad596006c63baac8.txt' created successfully
#  File 'input/MSL_Note_c817c8c0d97e4b5da56e83a51209c325.txt' created successfully
#  File 'input/MSL_Note_373d6a2f38f34bdebd4849be4c4307db.txt' created successfully
#  File 'input/MSL_Note_a29baa12cc5441a7af90d1e47b72820a.txt' created successfully
#  File 'input/MSL_Note_8bda355cf5e54795b866f6beadd3d1e4.txt' created successfully
#  File 'input/MSL_Note_ebfca43ed1a84d30a67412887c0ee07c.txt' created successfully
#  File 'input/MSL_Note_41ccc2ab338e442caf52380d8bfba7db.txt' created successfully
#  File 'input/MSL_Note_442f4a06d1cc4261aa9f9c85965d62e2.txt' created successfully
#  File 'input/MSL_Note_e88aaeedc6ea4795949ee539f910eb23.txt' created successfully
#  File 'input/MSL_Note_8bfbb1cc693a45b9914cf6907a911fac.txt' created successfully
#  File 'input/MSL_Note_001c919daeb848298dff52eccd1cfa21.txt' created successfully
#  File 'input/MSL_Note_b9349075368e4141b433aa143c2c467f.txt' created successfully
#  File 'input/MSL_Note_561aa3887a4148c7948dcf132f51016d.txt' created successfully
#  File 'input/MSL_Note_8c85f57190bf4376a3cb3c22fa68260e.txt' created successfully
#  File 'input/MSL_Note_dfc6358cd1064909808ee03840dcfc26.txt' created successfully
#  File 'input/MSL_Note_281d9bcbd6f742ab8e9165d234266cb2.txt' created successfully
#  File 'input/MSL_Note_24baedbeef5e4cb0b128559e1888893d.txt' created successfully
#  File 'input/MSL_Note_7aafb2114c664800a1e0e70dda730713.txt' created successfully
#  File 'input/MSL_Note_f8ed3a20a5c74f6592ba70aca420279e.txt' created successfully
#  File 'input/MSL_Note_75cea5c51cdc4ed3b0dd928aae2528d3.txt' created successfully
#  File 'input/MSL_Note_720cae05b14542c9840933d070f0bf5a.txt' created successfully
#  File 'input/MSL_Note_a970d9b052b94b9c9592661e6385b6eb.txt' created successfully
#  File 'input/MSL_Note_203056e459854d17ad0e5bdf63ef73ae.txt' created successfully
#  File 'input/MSL_Note_d1e117e08efa4dc6af1b71e1ed56a6b2.txt' created successfully
#  File 'input/MSL_Note_1e0e9e08385846ee824987ab14c4dd43.txt' created successfully
#  File 'input/MSL_Note_7efeee0a9dcf4ab4905d215be3d48704.txt' created successfully
#  File 'input/MSL_Note_9d178e28008548a2b1c191463a8a2b6a.txt' created successfully
#  File 'input/MSL_Note_8c4f9acd1cc94a7cba9fc11d052008b5.txt' created successfully
#  File 'input/MSL_Note_36d8f5f1b0894fd98c762655e3ee7aba.txt' created successfully
#  File 'input/MSL_Note_4953085305d44604b056e35b412383cc.txt' created successfully
#  File 'input/MSL_Note_5295e30a99ba43fea78542c624996f0e.txt' created successfully
#  File 'input/MSL_Note_6edc8c222831413d8fe1ec4ce830a5d2.txt' created successfully
#  File 'input/MSL_Note_b5eacc7b58fe45ac8be1fc97ede91f30.txt' created successfully
#  File 'input/MSL_Note_aac9a0b0e19e4851bc8c6f1f55b8e724.txt' created successfully
#  File 'input/MSL_Note_d5e38008307f4196b75fbd51c55cc712.txt' created successfully
#  File 'input/MSL_Note_b05199477b324f5c89d956841b5d909c.txt' created successfully
#  File 'input/MSL_Note_0b840f377a9c4ccabf0f758a340c8184.txt' created successfully
#  File 'input/MSL_Note_545a224c986d4fec8fe53a36a06a1e99.txt' created successfully
#  File 'input/MSL_Note_a9702bb2580548e4a8f082b5013e1c59.txt' created successfully
#  File 'input/MSL_Note_1f5e4ce6f68e4388af555c809561332e.txt' created successfully
#  File 'input/MSL_Note_5e473d9c7b53466a8b65bf6fd76fd5f0.txt' created successfully
#  File 'input/MSL_Note_929e83d597944e2d94fed718c2e5ade4.txt' created successfully
#  File 'input/MSL_Note_de282fe0d975480d845ee1ce6b9728ac.txt' created successfully
#  File 'input/MSL_Note_02ebef90ecb743549a5b98e3bd7b840e.txt' created successfully
#  File 'input/MSL_Note_b4342457f42140749e967391ad1af663.txt' created successfully
#  File 'input/MSL_Note_2e7efb3a8c15498dbc872bba53993d74.txt' created successfully
#  File 'input/MSL_Note_708f9703556d497ab640f1ae9c422bde.txt' created successfully
#  File 'input/MSL_Note_ebd75a41a3f94714ab6180110b85c57a.txt' created successfully
#  File 'input/MSL_Note_23aed5be223a419082ee798261815f74.txt' created successfully
#  File 'input/MSL_Note_5c17c36a1e144c4e9f70049dd613b2ac.txt' created successfully
#  File 'input/MSL_Note_c523771710bf497a9d81567f0fdd2760.txt' created successfully
#  File 'input/MSL_Note_f39511ba25ab45938734193031fd217f.txt' created successfully
#  File 'input/MSL_Note_9fa012c47d054d6fb1773042ca30edd0.txt' created successfully
#  File 'input/MSL_Note_29de6ac7a49845bcbdce2a7fdba90b9b.txt' created successfully
#  File 'input/MSL_Note_0d7d1e7140664e9ba9f5a4425ef5db28.txt' created successfully
#  File 'input/MSL_Note_b0cee26bc5a74bb69e4a1c781c405b50.txt' created successfully
#  File 'input/MSL_Note_db69ca8a6a6742bfae501fc774a1437c.txt' created successfully
#  File 'input/MSL_Note_69d816e6b04943da970b5d5254a557a7.txt' created successfully
#  File 'input/MSL_Note_0066d542b682405fb8ecd101c0179b42.txt' created successfully
#  File 'input/MSL_Note_86e9dc2bf7994b6fb772b6ce7b138484.txt' created successfully
#  File 'input/MSL_Note_7313cafbfd1b481e9d2af48fa8e0c454.txt' created successfully
#  File 'input/MSL_Note_0acc8022bd4d4e6fb61cf7c2ca2f2534.txt' created successfully
#  File 'input/MSL_Note_9d1fa25c32e24bdaa52c9cc148a51d8f.txt' created successfully
#  File 'input/MSL_Note_0e56348bf99b43498157529124d42e5b.txt' created successfully
#  File 'input/MSL_Note_08da6a7c8cf94504ba5a20ddf33fddde.txt' created successfully
#  File 'input/MSL_Note_e8749a616bc2485eab954343a998059d.txt' created successfully
#  File 'input/MSL_Note_ce495988318840ecb663668d4e2a42c2.txt' created successfully
#  File 'input/MSL_Note_149c6474546d4e59bed45f7f0fc2771a.txt' created successfully
#  File 'input/MSL_Note_797492442c834c79822aed6ee000bf88.txt' created successfully
#  File 'input/MSL_Note_1afe89a75a00425c86a944169f5d41bb.txt' created successfully
#  File 'input/MSL_Note_28c756b026474b78a934f04cf08d3c90.txt' created successfully
#  File 'input/MSL_Note_5afd57e08f9c41d1b0dd39efd03d3eb9.txt' created successfully
#  File 'input/MSL_Note_0cb3af3e7eb341b682e4962a35c29f96.txt' created successfully
#  File 'input/MSL_Note_960378b4c5f34986a6b333303f2b13a6.txt' created successfully
#  File 'input/MSL_Note_ffdd38f9af244e608f185eb12dfb27fc.txt' created successfully
#  File 'input/MSL_Note_6a9a282d9cb34d8fa8e5f7faf9d5f2cf.txt' created successfully
#  File 'input/MSL_Note_096f48568b8d4cbfb76c17f59349482d.txt' created successfully
#  File 'input/MSL_Note_e8d7d8a8c8cd435484de02fe11b25d70.txt' created successfully
#  File 'input/MSL_Note_383a0d69ac314d67b9b612ac35260f37.txt' created successfully
#  File 'input/MSL_Note_643aab4c7add45bea7bbeb2ebd506b59.txt' created successfully
#  File 'input/MSL_Note_2ddb8f6a35244f0eac38940e1055d859.txt' created successfully
#  File 'input/MSL_Note_45216149865c4f5d987dd81c0894add4.txt' created successfully
#  File 'input/MSL_Note_3b0905bbe4074b1abd914292be51eade.txt' created successfully
#  File 'input/MSL_Note_fec2216a385f4b3f9f2b0b0e8327bfb9.txt' created successfully
#  File 'input/MSL_Note_bc31a78d79ed4c59bf36411a4e256483.txt' created successfully
#  File 'input/MSL_Note_9f0e7550711d453692357221f88e635e.txt' created successfully
#  File 'input/MSL_Note_e50be7ef401f41fc9907f91fe8e9b695.txt' created successfully
#  File 'input/MSL_Note_03be3f1622af458aa7726a4adc10bc28.txt' created successfully
#  File 'input/MSL_Note_fa5355eb5ad6485c8e528e58dbfe7d7a.txt' created successfully
#  File 'input/MSL_Note_5aa264cddc1042e8bc07eb353934ae24.txt' created successfully
#  File 'input/MSL_Note_356bd4042f96443ea8808adcce864c01.txt' created successfully
#  File 'input/MSL_Note_934fcc18d22340f28f80e35f6eba062a.txt' created successfully
#  File 'input/MSL_Note_db18ced13f07459ab9b78162f36f903d.txt' created successfully
#  File 'input/MSL_Note_592a6ea893414525a10e5a47211bf2fe.txt' created successfully
#  File 'input/MSL_Note_e60181abb2b94305aba9f31bdf03eb35.txt' created successfully
#  File 'input/MSL_Note_a040b3aa967f42cbb2b0dbee67a799b0.txt' created successfully
#  File 'input/MSL_Note_6be6a92a92474bec887ac950add722f7.txt' created successfully
#  File 'input/MSL_Note_c77d44b12cbe41ac9df2cd60144329f1.txt' created successfully
#  File 'input/MSL_Note_545315f835f549b39c2e4ec28b13e8f2.txt' created successfully
#  File 'input/MSL_Note_8071143366be4027ab1dec124605181c.txt' created successfully
#  File 'input/MSL_Note_34dfc2aef305434fb6a8fee3c45b7153.txt' created successfully
#  File 'input/MSL_Note_dc86647229d045cebf7a3f1cb4314373.txt' created successfully
#  File 'input/MSL_Note_05e018f1c7ca462b9ba9eca6696c9610.txt' created successfully
#  File 'input/MSL_Note_92fa8176407f463ba9e5464afa53cdb7.txt' created successfully
#  File 'input/MSL_Note_cb58fd807eb94929961202350c5656e1.txt' created successfully
#  File 'input/MSL_Note_254e8e7cd6d14e3dbc4d3d2e7affb9a5.txt' created successfully
#  File 'input/MSL_Note_470954536588468ebfcb853d3d7409c7.txt' created successfully
#  File 'input/MSL_Note_1ceb065f4bfa4b43838bd728ea18e7b7.txt' created successfully
#  File 'input/MSL_Note_4dab5b3a14474533bfa272d4ad402064.txt' created successfully
#  File 'input/MSL_Note_be1e873abfd44315a5a07db5365ed4af.txt' created successfully
#  File 'input/MSL_Note_bd0cfcf3e2c9405cb3bba97de67e3355.txt' created successfully
#  File 'input/MSL_Note_c898b5c0f6474fd98d0845f4bc8b1278.txt' created successfully
#  File 'input/MSL_Note_5fc154bde8d34dfb8f7e8bcfffb9d594.txt' created successfully
#  File 'input/MSL_Note_c79ee4212bf745868b1be1f896710d3d.txt' created successfully
#  File 'input/MSL_Note_5ceae7e81e594a20bff2ccc94a2456e1.txt' created successfully
#  File 'input/MSL_Note_49d07e95cfd04d76aba2cca4d8af057e.txt' created successfully
#  File 'input/MSL_Note_d6875fa6464f49beb136adaa9d5f2cb3.txt' created successfully
#  File 'input/MSL_Note_2dab74b9a9ac47129aedd06c4fbc180c.txt' created successfully
#  File 'input/MSL_Note_1ccf283bef074ddb88b4ed252631c749.txt' created successfully
#  File 'input/MSL_Note_973f0946539e481b919013ed459d27c3.txt' created successfully
#  File 'input/MSL_Note_2b32e1cf89374348b95a8c73857b764b.txt' created successfully
#  File 'input/MSL_Note_1571a7a5314142b68821d8c0971bafb6.txt' created successfully
#  File 'input/MSL_Note_c18fa025c2d146de9cca44e9216c2eb6.txt' created successfully
#  File 'input/MSL_Note_69b4d9b2e75246728756dc406e6c83f3.txt' created successfully
#  File 'input/MSL_Note_3caf8d18d16e45b3aae854436d4cc6cf.txt' created successfully
#  File 'input/MSL_Note_4b93c4ed57974b0b8f9bf3017c760fc6.txt' created successfully
#  File 'input/MSL_Note_f8138ae547a04bf8a2e1c80707d5cf56.txt' created successfully
#  File 'input/MSL_Note_9c860bfb4601448ebe1e8f62543edf67.txt' created successfully
#  File 'input/MSL_Note_023f479c503d46b189fda568bdc9f2c1.txt' created successfully
#  File 'input/MSL_Note_113b9789be1d4329bf233533d5784497.txt' created successfully
#  File 'input/MSL_Note_04df900d1b0943569c7d465d40594827.txt' created successfully
#  File 'input/MSL_Note_b8eee8fd4d564ad8a7c5adb83ce9fbc2.txt' created successfully
#  File 'input/MSL_Note_ba2ec5ee75bd496f9d964e5c6c335874.txt' created successfully
#  File 'input/MSL_Note_60501b9240474335ab4a5f73074bffd9.txt' created successfully
#  File 'input/MSL_Note_ad002b52d8e844698efd91ee2eb46702.txt' created successfully
#  File 'input/MSL_Note_6e0a401918504afe9a7f068ddbb40de7.txt' created successfully
#  File 'input/MSL_Note_6c9e4bbe5d58485fbacc796be241cb63.txt' created successfully
#  File 'input/MSL_Note_ddacdb5679ca408386f998f32c917f6d.txt' created successfully
#  File 'input/MSL_Note_fd97f5d458db41b7ad942b8653e30251.txt' created successfully
#  File 'input/MSL_Note_c8ee8e4e2b694f1f99c952be18ca365f.txt' created successfully
#  File 'input/MSL_Note_31901b88ff3c48d8bed8969ded006f19.txt' created successfully
#  File 'input/MSL_Note_1c6823b9de12431b87037108e9302b12.txt' created successfully
#  File 'input/MSL_Note_009789b75a6d46818b14348d2ee75aa7.txt' created successfully
#  File 'input/MSL_Note_e20fd500b851491f83407335f96dc674.txt' created successfully
#  File 'input/MSL_Note_665405bc39654c66958c305bc5761a1d.txt' created successfully
#  File 'input/MSL_Note_dc4d58d658da40dba795ebeed4bc73e7.txt' created successfully
#  File 'input/MSL_Note_08eb2a0542a245cdb25382888c42fb57.txt' created successfully
#  File 'input/MSL_Note_56bb70392fca49c8a72c2d42f6f656dc.txt' created successfully
#  File 'input/MSL_Note_3510a366e7374cfa83c28929c386d43d.txt' created successfully
#  File 'input/MSL_Note_5efef7a46c0a4f6b8211904315c0bd73.txt' created successfully
#  File 'input/MSL_Note_622c793a3460404694be63280cc8624b.txt' created successfully
#  File 'input/MSL_Note_a9ae0c8255424bbb880176c34ba14a0d.txt' created successfully
#  File 'input/MSL_Note_8b1a3be4a7c64fdeafd62a5033064e2c.txt' created successfully
#  File 'input/MSL_Note_e810e92fa4474b059e73efbe9acf0f50.txt' created successfully
#  File 'input/MSL_Note_37c232737b964a54a91475c9b209c201.txt' created successfully
#  File 'input/MSL_Note_9cf3bbb4bbba4a489e81a63bf50349dd.txt' created successfully
#  File 'input/MSL_Note_4b8737427f8542259f7542edc5117449.txt' created successfully
#  File 'input/MSL_Note_5720d0ba20994bbeb56ea04ce193f301.txt' created successfully
#  File 'input/MSL_Note_64d8463579b440829611d5e5ad69d9e2.txt' created successfully
#  File 'input/MSL_Note_391acef43d384c1da9e20a9dcedce769.txt' created successfully
#  File 'input/MSL_Note_4e51f7458f8e4f838103d221840bb8a8.txt' created successfully
#  File 'input/MSL_Note_ec03f74762594b699eec11711a8c4a02.txt' created successfully
#  File 'input/MSL_Note_f854bc2e9c684232b0c391fa8d10ab67.txt' created successfully
#  File 'input/MSL_Note_e6af32ee56634d8a9acbc49e1661ba1a.txt' created successfully
#  File 'input/MSL_Note_09eeaacce92c4d1db654d6114f5a126a.txt' created successfully
#  File 'input/MSL_Note_d0b6af225b1c48ad95071d7a4e71a9e2.txt' created successfully
#  File 'input/MSL_Note_aa75448948b241249e35e76b44db444c.txt' created successfully
#  File 'input/MSL_Note_0a8031a7daeb4d428fa7110c642d6a8d.txt' created successfully
#  File 'input/MSL_Note_5ac3252738324e63b976ca99229e50d9.txt' created successfully
#  File 'input/MSL_Note_8e3ff14522ee4e10b07dabcdb65bb47b.txt' created successfully
#  File 'input/MSL_Note_21625272524f4e6fbcc4d93762dc14e3.txt' created successfully
#  File 'input/MSL_Note_66209604e732440cb8b1ae13e065d82b.txt' created successfully
#  File 'input/MSL_Note_548f800289d14abdb9f368738d8667e2.txt' created successfully
#  File 'input/MSL_Note_ed407d275c114de48e93216475632163.txt' created successfully
#  File 'input/MSL_Note_670f9a5aaa104893a9d65fafe0695cec.txt' created successfully
#  File 'input/MSL_Note_666cc412c6404d3eacc4c2accaf28cf5.txt' created successfully
#  File 'input/MSL_Note_03fb0235b6344581862c79410938e420.txt' created successfully
#  File 'input/MSL_Note_03ded1cd323d4638affbcb32e8ce98f1.txt' created successfully
#  File 'input/MSL_Note_bfe16d3b1c984fba993ff8974185d253.txt' created successfully
#  File 'input/MSL_Note_5f6c55309343404e92b9e0c252495d07.txt' created successfully
#  File 'input/MSL_Note_1bad0ca6a7c04339a1894c0b895786bf.txt' created successfully
#  File 'input/MSL_Note_bffc0696d46f4f66b70263b12b45b06b.txt' created successfully
#  File 'input/MSL_Note_fd6fc32f63fa4d589ed32166efc83157.txt' created successfully
#  File 'input/MSL_Note_c09bec9d64324c188db91d9d122c8d3b.txt' created successfully
#  File 'input/MSL_Note_6c00ccba238a428fbf4879a683c63b80.txt' created successfully
#  File 'input/MSL_Note_5e73bcbbe72c4ca987f111e02193dc65.txt' created successfully
#  File 'input/MSL_Note_c62b7ec7db854f47a61d1e89e89a22b8.txt' created successfully
#  File 'input/MSL_Note_e8675b64a8d74ea2960c37556a816e01.txt' created successfully
#  File 'input/MSL_Note_a17c4bad185944f28e356b8184bc2c5c.txt' created successfully
#  File 'input/MSL_Note_0867c0f677fe4c94a8df3a1c55465bf1.txt' created successfully
#  File 'input/MSL_Note_c6cecdd0678e44f89e26363085baf57e.txt' created successfully
#  File 'input/MSL_Note_954a5b773d074f58b928c989260ad9d8.txt' created successfully
#  File 'input/MSL_Note_55169ce4695e409182f14ec138de666e.txt' created successfully
#  File 'input/MSL_Note_74d19a0354dd41838407f77aaf1a2528.txt' created successfully
#  File 'input/MSL_Note_c10c1b90141a4da684a26ffe76fa83bb.txt' created successfully
#  File 'input/MSL_Note_8eecbe7e51d047e392790f9c97c2a8e3.txt' created successfully
#  File 'input/MSL_Note_93de274ffff8442496224c4a44173b5b.txt' created successfully
#  File 'input/MSL_Note_3d1f99a21fb04f9aa03745e0e0b446c0.txt' created successfully
#  File 'input/MSL_Note_cd64040f396841539549cd95ab4a809d.txt' created successfully
#  File 'input/MSL_Note_daa1b1455120495f8ff3eaa39c612577.txt' created successfully
#  File 'input/MSL_Note_22cfc928b79440e08ecf255d7ee4b5b3.txt' created successfully
#  File 'input/MSL_Note_4767e61f7277496c897a70a1b3f45e58.txt' created successfully
#  File 'input/MSL_Note_a36d6d407b40432d83ec3ebf41af40ce.txt' created successfully
#  File 'input/MSL_Note_98eee37aebe54446a7e0504ed89dc38c.txt' created successfully
#  File 'input/MSL_Note_0c46e275a5604539842a5d19b9af4707.txt' created successfully
#  File 'input/MSL_Note_8eca2db99c584987939e600d63b2357c.txt' created successfully
#  File 'input/MSL_Note_d1b38ddf4ef1445d91b1323f1391ad28.txt' created successfully
#  File 'input/MSL_Note_da0444bcde6847759fa7d496c1fb4d24.txt' created successfully
#  File 'input/MSL_Note_3effbe4c68b94c65a0984e6d45044ac6.txt' created successfully
#  File 'input/MSL_Note_0cab1faaa5094b8b8d67807b28674126.txt' created successfully
#  File 'input/MSL_Note_12a2a0b428104bf6a83931a849f8d06e.txt' created successfully
#  File 'input/MSL_Note_f46b9584e878411a8a29efd1cef5fa90.txt' created successfully
#  File 'input/MSL_Note_e81d3d05e6c1490495a3e28b4244ed45.txt' created successfully
#  File 'input/MSL_Note_11f312d88c734cb79aecec6a55abfdf5.txt' created successfully
#  File 'input/MSL_Note_097917e5c5ce42a6899b5b056060aeae.txt' created successfully
#  File 'input/MSL_Note_c6d31daf290343a99e9d5ed7bdadd310.txt' created successfully
#  File 'input/MSL_Note_da5ae216125e4e038e602dc3754222b6.txt' created successfully
#  File 'input/MSL_Note_2f3e489f88d5406aa5e8fa728487a535.txt' created successfully
#  File 'input/MSL_Note_7f11f5738c4d4b12938a229179772951.txt' created successfully
#  File 'input/MSL_Note_91fa4ad599644852ab4790456ba65d56.txt' created successfully
#  File 'input/MSL_Note_4ffdb994f6004ae1961bc46ab2a4ca2f.txt' created successfully
#  File 'input/MSL_Note_2ddaf7b9f8ff471899113cc0a02288bf.txt' created successfully
#  File 'input/MSL_Note_be1debcfb21b4c068a4560ee6914e03d.txt' created successfully
#  File 'input/MSL_Note_0c9b8d4d4ba44ccd90cd851b39693002.txt' created successfully
#  File 'input/MSL_Note_69fa945d536b45c49d2c7e66cdf6eb63.txt' created successfully
#  File 'input/MSL_Note_1ebc4e255b3a401aa3fb22dea13f7d0f.txt' created successfully
#  File 'input/MSL_Note_5a79b08e42074849abcf215b23859fad.txt' created successfully
#  File 'input/MSL_Note_a6a83b6ac13345c3b7526d36d0e6e265.txt' created successfully
#  File 'input/MSL_Note_5ccbdc8716894c3491c3ab2266e13a70.txt' created successfully
#  File 'input/MSL_Note_9fc1dc53cfba46c5b57cc2f8d0d8b6a6.txt' created successfully
#  File 'input/MSL_Note_53ad3009ca6a477c87f9eeaf1296f8ab.txt' created successfully
#  File 'input/MSL_Note_7ab41fcad8de4edc86b0167d60926a8c.txt' created successfully
#  File 'input/MSL_Note_20d70dcd3cd34552b5ea9e82015daa83.txt' created successfully
#  File 'input/MSL_Note_411fb84f5b834566be7e48a8e09b120c.txt' created successfully
#  File 'input/MSL_Note_17af1e9914f447b196a0520b20e05516.txt' created successfully
#  File 'input/MSL_Note_7b8ec4095aab45f0844fa12dea1fc1c4.txt' created successfully
#  File 'input/MSL_Note_b7a6ab10e9d94c20b8542d23efa10f33.txt' created successfully
#  File 'input/MSL_Note_b118ab1b852c4015a4f2366c10a30ec7.txt' created successfully
#  File 'input/MSL_Note_17b5971b7e224ea6ae33c97445106735.txt' created successfully
#  File 'input/MSL_Note_075658abea7b4776b918f1dbb41d03d4.txt' created successfully
#  File 'input/MSL_Note_e563a8486029499b8fb584731e6c3e20.txt' created successfully
#  File 'input/MSL_Note_254fcd982326444da985a3d5fedde33f.txt' created successfully
#  File 'input/MSL_Note_c69a66027f5e4f1b9a69186545fd26e6.txt' created successfully
#  File 'input/MSL_Note_69892c59bafa40f69d65fa6e41be4f76.txt' created successfully
#  File 'input/MSL_Note_1ecb6b0c1eb243fda27c5fcb07896e12.txt' created successfully
#  File 'input/MSL_Note_f51fd2e5c47c498b812f39f55557f572.txt' created successfully
#  File 'input/MSL_Note_017d441ed0bd40ba833a87179ddde8e9.txt' created successfully
#  File 'input/MSL_Note_fd5afaf1599849ed8ae1cda01b58786e.txt' created successfully
#  File 'input/MSL_Note_000d0d8ba41e45deb3bfa9be129722c2.txt' created successfully
#  File 'input/MSL_Note_0630294adc594b11ba54adc6ec3b50bb.txt' created successfully
#  File 'input/MSL_Note_cdd38403fd9d42ec94fb23d480994c50.txt' created successfully
#  File 'input/MSL_Note_e0b353066ec44ca287d2a300204589f7.txt' created successfully
#  File 'input/MSL_Note_aaa591a55c6f433d9349073ba961538b.txt' created successfully
#  File 'input/MSL_Note_54c1a63d5bcc4dbe92598067bca245d8.txt' created successfully
#  File 'input/MSL_Note_e3f214dff9ce445095b7b451ce43aec2.txt' created successfully
#  File 'input/MSL_Note_799a3700767946728aaaea536c837bab.txt' created successfully
#  File 'input/MSL_Note_68739f57479b421093631c832d56ab88.txt' created successfully
#  File 'input/MSL_Note_f2dec3df68fe47d28f87483ea84b485e.txt' created successfully
#  File 'input/MSL_Note_1887fd389896462e8c893c2bcb3bd182.txt' created successfully
#  File 'input/MSL_Note_ff1b8ef649ff482aa759ac7f2af1a5c8.txt' created successfully
#  File 'input/MSL_Note_301f86d106cc411c935a45633cb092dc.txt' created successfully
#  File 'input/MSL_Note_0fea966827174482aca1784fa9ae6156.txt' created successfully
#  File 'input/MSL_Note_b11ade7a52d94caebaebf79e2b6d190a.txt' created successfully
#  File 'input/MSL_Note_834d74494cde4e08b279ad0be089597b.txt' created successfully
#  File 'input/MSL_Note_fb4c8d9f46df4d55b050e9e47efc1d98.txt' created successfully
#  File 'input/MSL_Note_3034a860aee84746b68d3510c0d1584a.txt' created successfully
#  File 'input/MSL_Note_1eaaa303c6104bb59418f574d80d3ba6.txt' created successfully
#  File 'input/MSL_Note_fbe35da9a93b4f7c99250535e099f0e8.txt' created successfully
#  File 'input/MSL_Note_aff9fa79871d4a10b998437df5e849bc.txt' created successfully
#  File 'input/MSL_Note_61f7f4e17cae4b50bdd23f9fd1e60032.txt' created successfully
#  File 'input/MSL_Note_1685ad05bd4c444592d814ebba7c6274.txt' created successfully
#  File 'input/MSL_Note_1b8f1d9da118432ab7b82f495462c65d.txt' created successfully
#  File 'input/MSL_Note_b0839bef72874705bf634839dd9d2ec9.txt' created successfully
#  File 'input/MSL_Note_5ab0c8886bcc45789316c0045944f13a.txt' created successfully
#  File 'input/MSL_Note_f4f651a2e89146a3a6b98ebf71e50faf.txt' created successfully
#  File 'input/MSL_Note_1f381e5dcdc44a13b39ccbdd37df3278.txt' created successfully
#  File 'input/MSL_Note_23b968c82b6f4979932b954ef987c8bd.txt' created successfully
#  File 'input/MSL_Note_5ccd83659a17440d8b476a0dad43aa95.txt' created successfully
#  File 'input/MSL_Note_6dc9044904b44c2e89ebd3a37b26d58f.txt' created successfully
#  File 'input/MSL_Note_83b952d959914c6ca92397210a0861e3.txt' created successfully
#  File 'input/MSL_Note_90ac4378261747afa78956b4545e2863.txt' created successfully
#  File 'input/MSL_Note_b6804ea92e11450d800908a5994aae8a.txt' created successfully
#  File 'input/MSL_Note_4b3eae3d6bdc485982db5eb1a9264877.txt' created successfully
#  File 'input/MSL_Note_15f644be4576483a960fafb808ef0187.txt' created successfully
#  File 'input/MSL_Note_706b0a0277794879bbda0034a526cb8d.txt' created successfully
#  File 'input/MSL_Note_369f5713df4c43f69bf1d997d58d7db5.txt' created successfully
#  File 'input/MSL_Note_f23f387ef6b94b67b3f5391de2f6552f.txt' created successfully
#  File 'input/MSL_Note_0ff6fb7df1274060b70945ed1621e91b.txt' created successfully
#  File 'input/MSL_Note_9f045016d6e34fc9937c6ad065c5389c.txt' created successfully
#  File 'input/MSL_Note_beebbd4437824a69b4ab3b8091106aa6.txt' created successfully
#  File 'input/MSL_Note_729b8df04f954c258a9b7849c1fcef12.txt' created successfully
#  File 'input/MSL_Note_aaec6937fbb64483a36cdd67c22ee390.txt' created successfully
#  File 'input/MSL_Note_e192f49decc44edcb873c286363b2277.txt' created successfully
#  File 'input/MSL_Note_14dede94e7084c7891e98e75c1e43fdd.txt' created successfully
#  File 'input/MSL_Note_0cb2047957f542639443115d455a67e8.txt' created successfully
#  File 'input/MSL_Note_1168de85ef424c5c99ded0106306c8a4.txt' created successfully
#  File 'input/MSL_Note_6498c0bc3fd245a2a1ed6df93db7d6fb.txt' created successfully
#  File 'input/MSL_Note_c9a7ae8819c04e92aad459fa469243fb.txt' created successfully
#  File 'input/MSL_Note_90e269ca5e9c4fee97e8e87234549d1d.txt' created successfully
#  File 'input/MSL_Note_d995942d5fea435ea9bf4f49e19e5f1c.txt' created successfully
#  File 'input/MSL_Note_4ceb261b5f094e5782e167be85c30050.txt' created successfully
#  File 'input/MSL_Note_47be898ca75f4ebabce1edf8d6364361.txt' created successfully
#  File 'input/MSL_Note_84ecbdfd1ad34f3591eb8cb3629cdf92.txt' created successfully
#  File 'input/MSL_Note_21ec0807d68743fb92acafb8218b8069.txt' created successfully
#  File 'input/MSL_Note_13f9bfba4acc449fb596a64e209669e9.txt' created successfully
#  File 'input/MSL_Note_acd9e77fe2ef43eeb39e4a25289d00df.txt' created successfully
#  File 'input/MSL_Note_f14520261287407485f0979203d3915e.txt' created successfully
#  File 'input/MSL_Note_d74fb6e2a14a48c48a1675eed64126ea.txt' created successfully
#  File 'input/MSL_Note_5f348909594d47dbaa4ac57f6d127a32.txt' created successfully
#  File 'input/MSL_Note_f2223fbd5aef4f4ebd3bc41c97bb6967.txt' created successfully
#  File 'input/MSL_Note_0c97b3ee5eb2420ab13f60d7f4678a6a.txt' created successfully
#  File 'input/MSL_Note_2301c0e9500745859b57c6f710c7b0c9.txt' created successfully
#  File 'input/MSL_Note_2a055746f14a41429423f7163ec63aeb.txt' created successfully
#  File 'input/MSL_Note_c8a136dc2c9b45e7a55bfeb30312b918.txt' created successfully
#  File 'input/MSL_Note_fa38eaa077994907a8c236181b242004.txt' created successfully
#  File 'input/MSL_Note_e0eed49634354c1b8484ecc393547c5a.txt' created successfully
#  File 'input/MSL_Note_3b3925136c8b4ced8de73ccb680f8327.txt' created successfully
#  File 'input/MSL_Note_e38fcf2b3a344e94a7e09a63a6b7e708.txt' created successfully
#  File 'input/MSL_Note_31a419021abb41c48f0d744e8728e5c6.txt' created successfully
#  File 'input/MSL_Note_30cdb51c6bea481e9236c06a6a34e913.txt' created successfully
#  File 'input/MSL_Note_dd80b5e829af4b13bde50439673d9cbd.txt' created successfully
#  File 'input/MSL_Note_12b0195886ec45baa53887b561a62c56.txt' created successfully
#  File 'input/MSL_Note_99aaf2b4dd7341088c146c8db93fb48b.txt' created successfully
#  File 'input/MSL_Note_d20bec44c90342af8ac56c2eaf8c4e42.txt' created successfully
#  File 'input/MSL_Note_ef3880aa0e044b7bbf3b07a4553c2986.txt' created successfully
#  File 'input/MSL_Note_746d257f7df3415896fba2e6bf106807.txt' created successfully
#  File 'input/MSL_Note_5029973b08cf4e03a4cecfb33108718c.txt' created successfully
#  File 'input/MSL_Note_f74ea350aeaf441bb01d2021eac6a838.txt' created successfully
#  File 'input/MSL_Note_e88d89ccc56a4f42892bef9f37a9ebbb.txt' created successfully
#  File 'input/MSL_Note_232b1a56695e4ca090b264eabd81329b.txt' created successfully
#  File 'input/MSL_Note_b0eb9117731346cea6101f0a5d30e956.txt' created successfully
#  File 'input/MSL_Note_eecb54e9f7284d9faa1433127f2a19f3.txt' created successfully
#  File 'input/MSL_Note_020a687c578245809f7d056094406619.txt' created successfully
#  File 'input/MSL_Note_1f342ea6f2a54e55a34eca582f177bb1.txt' created successfully
#  File 'input/MSL_Note_416a5288137a4241b6606961ff2d18ba.txt' created successfully
#  File 'input/MSL_Note_ae71741755914d0d92aa00b46517c534.txt' created successfully
#  File 'input/MSL_Note_b576068328144d6d9ad83b8c70b14aa7.txt' created successfully
#  File 'input/MSL_Note_a35a08bdc7c74a36b4b98573ce3d583a.txt' created successfully
#  File 'input/MSL_Note_96ff38bf1e664e3c81cab0dc7a57af33.txt' created successfully
#  File 'input/MSL_Note_d09f6f8ec4284d6b880013ffb94f6be8.txt' created successfully
#  File 'input/MSL_Note_f3f3a36d979748ebac019d4f3068c97d.txt' created successfully
#  File 'input/MSL_Note_a955a2c6bad0478fa388eb1e7e84f8f4.txt' created successfully
#  File 'input/MSL_Note_7b1a935a23604e2f8388daa74e9e7a14.txt' created successfully
#  File 'input/MSL_Note_f4ecadd44849436da160e40f17027d54.txt' created successfully
#  File 'input/MSL_Note_a051d8049aa647c4bfa5ea382019b8f6.txt' created successfully
#  File 'input/MSL_Note_ab16e053a6004459912a4ec9b1d8b159.txt' created successfully
#  File 'input/MSL_Note_8f5ddf9832ab4774a9e585c224a677ca.txt' created successfully
#  File 'input/MSL_Note_21f3ce8111d34af9b7f04f0ee64c69bb.txt' created successfully
#  File 'input/MSL_Note_e1e085e264ee44e8b2c9f0eeaa6604b3.txt' created successfully
#  File 'input/MSL_Note_0bbe81ec93e74304a615d2d6a36189bc.txt' created successfully
#  File 'input/MSL_Note_e2a2fb5a2da044f5b38454b6b519cd8d.txt' created successfully
#  File 'input/MSL_Note_b575f4a66d7d4f23ba065f90f5963b74.txt' created successfully
#  File 'input/MSL_Note_d20943b2de40466eb394e8e389232a03.txt' created successfully
#  File 'input/MSL_Note_f7a4db1d856840da8267aae41977d643.txt' created successfully
#  File 'input/MSL_Note_b81b14dc929143409854e88489da0ca9.txt' created successfully
#  File 'input/MSL_Note_08ac4d8ac61549b0acf671e89d4b681a.txt' created successfully
#  File 'input/MSL_Note_bff0460cfbea4a8086d4d5270a31d323.txt' created successfully
#  File 'input/MSL_Note_8e5fc4288102430eb27a8ff18a70486a.txt' created successfully
#  File 'input/MSL_Note_ac36006ede1942bdb3d6a3b8b0e95a0b.txt' created successfully
#  File 'input/MSL_Note_903727938d6b44748279ecae7d9c619c.txt' created successfully
#  File 'input/MSL_Note_05608c20b6cc401e8ba9c3f6caf63598.txt' created successfully
#  File 'input/MSL_Note_4cd24639bac64d6bb028e0806fc2d879.txt' created successfully
#  File 'input/MSL_Note_00e0feae42cf45568adb357d4a9545b5.txt' created successfully
#  File 'input/MSL_Note_64e4ae998ee440319185cd0c672c932c.txt' created successfully
#  File 'input/MSL_Note_565ec79aed914ca986a3e4db94e47c3c.txt' created successfully
#  File 'input/MSL_Note_a362f06cb00c474b82f95867af4fb115.txt' created successfully
#  File 'input/MSL_Note_78719cfa079446b9bba9faa395936374.txt' created successfully
#  File 'input/MSL_Note_3d56f98db95349edacbdd77008f83167.txt' created successfully
#  File 'input/MSL_Note_19ce67eae6c0471293f1c86fc0b2a3c1.txt' created successfully
#  File 'input/MSL_Note_f912bdcb6323415785516f27ec20a548.txt' created successfully
#  File 'input/MSL_Note_1848143469354948b2043e24e4470c58.txt' created successfully
#  File 'input/MSL_Note_3e61b1171d2f403e922296413e315664.txt' created successfully
#  File 'input/MSL_Note_7eb3ffbc68b8451bad56d753e7b00255.txt' created successfully
#  File 'input/MSL_Note_c467c0ebb59d49afa4511956756b5892.txt' created successfully
#  File 'input/MSL_Note_8e721df5a22448eeac3c1684864bd485.txt' created successfully
#  File 'input/MSL_Note_2375c2cb9c294e698d4d9fbba20d9d66.txt' created successfully
#  File 'input/MSL_Note_1ef7fc4042684f72bdcbf59b6f9a3a3c.txt' created successfully
#  File 'input/MSL_Note_225f05f4a9e9425e92f61f144c5e2736.txt' created successfully
#  File 'input/MSL_Note_bbe6a6b046414716be4d6965d87ea279.txt' created successfully
#  File 'input/MSL_Note_c74a0dc85a0841d892c3e93a85ede934.txt' created successfully
#  File 'input/MSL_Note_35540ae30466499cbb08a543b36d7b50.txt' created successfully
#  File 'input/MSL_Note_c31e1d9688274720943008cf7e483d36.txt' created successfully
#  File 'input/MSL_Note_847ad823524b41cbacefa14a135ced9c.txt' created successfully
#  File 'input/MSL_Note_41bb44ecd00747ec851b37c02228ed7d.txt' created successfully
#  File 'input/MSL_Note_30822ef44bb54f9ea946cade1c1ce9b4.txt' created successfully
#  File 'input/MSL_Note_95dcc324d8f849d4b6a823325ac34a06.txt' created successfully
#  File 'input/MSL_Note_f39c531337d94715b3bf34da39d41207.txt' created successfully
#  File 'input/MSL_Note_83ee59b34a444202abce09cb639cf46e.txt' created successfully
#  File 'input/MSL_Note_3c20c77cb2624b4096a0d312d391a429.txt' created successfully
#  File 'input/MSL_Note_0ff4b795adfe4a489ec9feac64da0010.txt' created successfully
#  File 'input/MSL_Note_92b1af241d7a4e4ca01d562a803224f9.txt' created successfully
#  File 'input/MSL_Note_473cf0748a6d4de1b26a5e4a68b0723e.txt' created successfully
#  File 'input/MSL_Note_e180c87dde6d47238e06b78d4a3d6fcf.txt' created successfully
#  File 'input/MSL_Note_d09328d6f9cc4ebbb9074e065df75681.txt' created successfully
#  File 'input/MSL_Note_190af406d4664be4a5b66fa8bb47da7e.txt' created successfully
#  File 'input/MSL_Note_70c0f9b69f8747cc990b66a7dc39db87.txt' created successfully
#  File 'input/MSL_Note_f6320dfdff4a49d1bc413d3fc6436783.txt' created successfully
#  File 'input/MSL_Note_d4f11faa812b4a26ad0975c8ba96372d.txt' created successfully
#  File 'input/MSL_Note_34f008133c4c4060af3c77e30cf142e5.txt' created successfully
#  File 'input/MSL_Note_7003f853e1e84cbebea7fac16399177b.txt' created successfully
#  File 'input/MSL_Note_b94c5f7c17364f63bfd6d618c861aafc.txt' created successfully
#  File 'input/MSL_Note_a6d62e0a27c844e8bba1bf12e1002430.txt' created successfully
#  File 'input/MSL_Note_ae16ed15f3cc4de1ad43587f299a43a7.txt' created successfully
#  File 'input/MSL_Note_9caec9a67f584232ba7af88a5b6859d3.txt' created successfully
#  File 'input/MSL_Note_31c1c884500945e68310d099aff97c22.txt' created successfully
#  File 'input/MSL_Note_ea0fb6e9d98448ce994acb1b16a4455c.txt' created successfully
#  File 'input/MSL_Note_54076219ed5e433184b4c2349c095527.txt' created successfully
#  File 'input/MSL_Note_861ab4897a564e4a8390e4449a1dec9b.txt' created successfully
#  File 'input/MSL_Note_c86a65a2e40c4e9f88b84500d3e0e308.txt' created successfully
#  File 'input/MSL_Note_a2bf06a237034de29a7be495424ca449.txt' created successfully
#  File 'input/MSL_Note_ddad8b0cb7b24f429afad1c866059014.txt' created successfully
#  File 'input/MSL_Note_b087d320acf64b2cba434c4032728e77.txt' created successfully
#  File 'input/MSL_Note_7c1c2760441d491e9c924c59eb950fd5.txt' created successfully
#  File 'input/MSL_Note_28945381121e4e6cbd3bec6dab070694.txt' created successfully
#  File 'input/MSL_Note_897e90975d9b4ac097df6e66041e9694.txt' created successfully
# ...
#  File 'input/MSL_Note_f68e639a18084e9b94de5bda7d54954d.txt' created successfully
#  File 'input/MSL_Note_1db5ba315afe40ff904dee7b6fe37339.txt' created successfully
#  File 'input/MSL_Note_643c2bca58a24fa4a0141f9ec54391b1.txt' created successfully
#  File 'input/MSL_Note_bc11d117d43e43c48c28ca5a3d1a1ce4.txt' created successfully
#  File 'input/MSL_Note_aa4d9950a2a5471e8969659297767828.txt' created successfully
#  File 'input/MSL_Note_ab08e3e508ae443abdd0425f53d8b3be.txt' created successfully
#  File 'input/MSL_Note_7eea824876dd494789d8e3aea968648e.txt' created successfully
#  File 'input/MSL_Note_388bbe478ed1429e91673b92ea91c5c1.txt' created successfully
#  File 'input/MSL_Note_962fe97ea1b54db7bda9fc403dde4817.txt' created successfully
#  File 'input/MSL_Note_f2a8f12e0dc64dd7aff67248f967e979.txt' created successfully
#  File 'input/MSL_Note_1cfe92bc6dae4a37ae28a969168b839a.txt' created successfully
#  File 'input/MSL_Note_85195c76dff04610b048b99ccd7cf35c.txt' created successfully
#  File 'input/MSL_Note_e6cf21ded5414eb894a5f9aa5f3a0f22.txt' created successfully
#  File 'input/MSL_Note_7579ea1a085e4973881c8e7d474b4f33.txt' created successfully
#  File 'input/MSL_Note_93818c6597ed4d959875872204ac93c7.txt' created successfully
#  File 'input/MSL_Note_a2a48057dc684d1ebf5327ac3ce2fdb8.txt' created successfully
#  File 'input/MSL_Note_35b0c03a0c3c43b0a2592f7e1f2a12ae.txt' created successfully
#  File 'input/MSL_Note_b5f8afa82fe041d58abc5f1673374a94.txt' created successfully
#  File 'input/MSL_Note_75a72a26ea824b45b79468209827671c.txt' created successfully
#  File 'input/MSL_Note_1938d43d42354091a7a9badd05cf26a7.txt' created successfully
#  File 'input/MSL_Note_178b904e469b4ea7bb128b1cf6f1d136.txt' created successfully
#  File 'input/MSL_Note_fcd0e5a82bad486996eaa7e7d527c2bd.txt' created successfully
#  File 'input/MSL_Note_46f6c67823bb406d87b7b4385471c6cb.txt' created successfully
#  File 'input/MSL_Note_fb592f3213ed4b748af83e7acc414f88.txt' created successfully
#  File 'input/MSL_Note_2bdd2fa8d6e64261ba71ce921f28e919.txt' created successfully
#  File 'input/MSL_Note_0294df8dfe31444e912a38547c13aada.txt' created successfully
#  File 'input/MSL_Note_c07d788cc30341f0ba0612013978e8b6.txt' created successfully
#  File 'input/MSL_Note_5182ec452a2c417eae4a48a715c30421.txt' created successfully
#  File 'input/MSL_Note_eed099014f324a7bb9d3d3fa9ca33ac6.txt' created successfully
#  File 'input/MSL_Note_d0d19a9af7754c7aab2179d17273f955.txt' created successfully
#  File 'input/MSL_Note_5e81fbfee2c34ccb8b345c74a78335a2.txt' created successfully
#  File 'input/MSL_Note_6d090f9ff2084d8586d84693795bd581.txt' created successfully
#  File 'input/MSL_Note_bccec3a2fb1e4c05be0b703e4abd4de1.txt' created successfully
#  File 'input/MSL_Note_77b23a5cdfad4822aa7a0ad6c00fcb81.txt' created successfully
#  File 'input/MSL_Note_36a41b5d504542219f81b38a50a37f49.txt' created successfully
#  File 'input/MSL_Note_61b57d6807de43e782cc177f6dd2a3b8.txt' created successfully
#  File 'input/MSL_Note_a14b311482e64f519aed55c8d06a5d96.txt' created successfully
#  File 'input/MSL_Note_0b86d807058d4e348a193abb25bb6e7f.txt' created successfully
#  File 'input/MSL_Note_e9144e34bf514011abc5fb27be25dae3.txt' created successfully
#  File 'input/MSL_Note_fd7af820099843619e4242c1fb4ffc1a.txt' created successfully
#  File 'input/MSL_Note_e883426c44f84a5eb860431db1b60266.txt' created successfully
#  File 'input/MSL_Note_b3f03bff90bf45e187fa140b5b16bb47.txt' created successfully
#  File 'input/MSL_Note_49190e9f593643659ea96e5c663e13b4.txt' created successfully
#  File 'input/MSL_Note_5f5ef22f05a64f099046bc960c63ef52.txt' created successfully
#  File 'input/MSL_Note_dc74e45d7a514759be35bc3ac1fc3665.txt' created successfully
#  File 'input/MSL_Note_0f581c475f3d4c36bf821601f9099e25.txt' created successfully
#  File 'input/MSL_Note_0ea51b7aec6749e891d0ee993c55129d.txt' created successfully
#  File 'input/MSL_Note_e751878e1ef045f4b6a6a868a7954132.txt' created successfully
#  File 'input/MSL_Note_c3004f50482b4d87a4b3ea1d15f3eca9.txt' created successfully
#  File 'input/MSL_Note_279df9dd326046119e46f40a82fa40fa.txt' created successfully
#  File 'input/MSL_Note_91dc0e6f5df44913afa27cb548bbc793.txt' created successfully
#  File 'input/MSL_Note_e0253f7dfffd4181867822759b77c911.txt' created successfully
#  File 'input/MSL_Note_e841210005e244bfbb1adb3b6a37c574.txt' created successfully
#  File 'input/MSL_Note_c7a3a6e05aa8408d9cd9e4bdcce1ad76.txt' created successfully
#  File 'input/MSL_Note_a39c5024ad4f4d24a1ce5be1d95d91f0.txt' created successfully
#  File 'input/MSL_Note_2b6b4dccb2c04917b6cef3c6a542c9d4.txt' created successfully
#  File 'input/MSL_Note_f242fe3561d7480297afe2bb69b92d1d.txt' created successfully
#  File 'input/MSL_Note_3f65de10f70342a79ee0550da66a968e.txt' created successfully
#  File 'input/MSL_Note_2c94e347a41342c1873a042c5a22a3f3.txt' created successfully
#  File 'input/MSL_Note_423c00711f4748a68904f2e977e59ddd.txt' created successfully
#  File 'input/MSL_Note_cbef037787d04a5eba61bca1008d0bca.txt' created successfully
#  File 'input/MSL_Note_2d635442cd0f44988555f5124d78bacf.txt' created successfully
#  File 'input/MSL_Note_abf9b0571b9f455faff6a554cfdc7a3c.txt' created successfully
#  File 'input/MSL_Note_e3917e7aa1354bd58cf3f4cea7bb368f.txt' created successfully
#  File 'input/MSL_Note_57e80f875e55467d9e5dd944190160f5.txt' created successfully
#  File 'input/MSL_Note_ed136a65b79b4585823eb38f287f693b.txt' created successfully
#  File 'input/MSL_Note_85b90c17d11640ecb7e83bf26f39c0d2.txt' created successfully
#  File 'input/MSL_Note_baced4a729924a5289af087871505cc2.txt' created successfully
#  File 'input/MSL_Note_4c01e31a91f54dd49530696bd2b64a91.txt' created successfully
#  File 'input/MSL_Note_97b3dbb5b4604f288191fe07bf251829.txt' created successfully
#  File 'input/MSL_Note_c632e650a08145dba9452bb85f441d3e.txt' created successfully
#  File 'input/MSL_Note_117b2f6da5b84be1a7a8ed0d5e70be5c.txt' created successfully
#  File 'input/MSL_Note_5d6b20a53fe84337a26713537da6cf6a.txt' created successfully
#  File 'input/MSL_Note_6250faf354c5410eab37509fc0c3cc07.txt' created successfully
#  File 'input/MSL_Note_3170816cfb5647bdab748b8ad160948b.txt' created successfully
#  File 'input/MSL_Note_5d59829eac4d45e590e97e7070c84061.txt' created successfully
#  File 'input/MSL_Note_39ba10fba1f34931ac3184b5d28df7d7.txt' created successfully
#  File 'input/MSL_Note_9682f6690467405a8880fae898882b3a.txt' created successfully
#  File 'input/MSL_Note_8ab739b929634f9583e02dffd30a71f4.txt' created successfully
#  File 'input/MSL_Note_66133aaacc714f59a1e727b4483552e4.txt' created successfully
#  File 'input/MSL_Note_b65c79d8866d4352ab69931c57fff7e4.txt' created successfully
#  File 'input/MSL_Note_1dadd953615347ccb8f06994404c0b1a.txt' created successfully
#  File 'input/MSL_Note_c8af40ff9396428eae63d5b436d4a31a.txt' created successfully
#  File 'input/MSL_Note_43622158841c47e0bc83b39ad5d7ba48.txt' created successfully
#  File 'input/MSL_Note_e25e3fbf5b5841b6b6ed638c86b07610.txt' created successfully
#  File 'input/MSL_Note_a4d36dcc89644047b3510de686b4cc24.txt' created successfully
#  File 'input/MSL_Note_3ca7598b14c14bc59336c340456937b4.txt' created successfully
#  File 'input/MSL_Note_cae80b74158e4f32b9ee351c6ba58c78.txt' created successfully
#  File 'input/MSL_Note_55be8683a80a4ddcadbec08f61a61859.txt' created successfully
#  File 'input/MSL_Note_1cdafef3db0b4002a0ac0502a6928f62.txt' created successfully
#  File 'input/MSL_Note_67f07329ae6c41c589f398a619677805.txt' created successfully
#  File 'input/MSL_Note_a30219a16a6e4ff0a47e0e5f44477726.txt' created successfully
#  File 'input/MSL_Note_12007622e0a0425c8c79d5d27d842a24.txt' created successfully
#  File 'input/MSL_Note_4ba31aa281744823afacc15af32bafb4.txt' created successfully
#  File 'input/MSL_Note_40ed4b40153d47cfb1e201339c811dc4.txt' created successfully
#  File 'input/MSL_Note_fdf3d716ec9642b69952ab22ec2092e9.txt' created successfully
#  File 'input/MSL_Note_dc8225627a0c4ac8aee986599a1796d1.txt' created successfully
#  File 'input/MSL_Note_89841799ee8a41e1b3019a72f6d21c0e.txt' created successfully
#  File 'input/MSL_Note_7894275ddf344e07b91621b8069aa6ec.txt' created successfully
#  File 'input/MSL_Note_503df0731fc04256b922b219bf1addbb.txt' created successfully
#  File 'input/MSL_Note_b4c1caca81c24ae9b5fa61991a12b533.txt' created successfully
#  File 'input/MSL_Note_df41d6c289de4594b0f7de7a16da4423.txt' created successfully
#  File 'input/MSL_Note_e26bd44ce95b4170b5b050457d3c72ba.txt' created successfully
#  File 'input/MSL_Note_2434fd9832c248289a17ae6b7ec88d50.txt' created successfully
#  File 'input/MSL_Note_c84329e793f34205921cd9b12c7c3550.txt' created successfully
#  File 'input/MSL_Note_e13a5ce8652f4fd082bc234eb3544d27.txt' created successfully
#  File 'input/MSL_Note_49cc6010606648b693e6d1d133fd9ee0.txt' created successfully
#  File 'input/MSL_Note_b3e8e07d417846479a5d17a746b38fee.txt' created successfully
#  File 'input/MSL_Note_3c841acd10794fe39406fd0d78e266b6.txt' created successfully
#  File 'input/MSL_Note_bcf5a5a71a7d48a09b6383ca55af637b.txt' created successfully
#  File 'input/MSL_Note_acaa5df93b8a47b882e832063da1b334.txt' created successfully
#  File 'input/MSL_Note_7e557ac7abd24b9c9eff064eb98a2b60.txt' created successfully
#  File 'input/MSL_Note_3062e70cf9e241d09b9209ab3dda7531.txt' created successfully
#  File 'input/MSL_Note_fc704ca474954f35be38516c1a978b33.txt' created successfully
#  File 'input/MSL_Note_e6a5428c6ddf4c5d98ef2a1579385cb9.txt' created successfully
#  File 'input/MSL_Note_79588e9c51fb4fe0ae9e0bfb27cd71f4.txt' created successfully
#  File 'input/MSL_Note_85d36ee15cda40068f56d1fa0f1d886b.txt' created successfully
#  File 'input/MSL_Note_53ee0e8775c249ac8aed3c6b71af2344.txt' created successfully
#  File 'input/MSL_Note_ac2850d0fc9644cdafe537c64c0ed0fd.txt' created successfully
#  File 'input/MSL_Note_80e0612cd34141eb8dd26cfdb835f1ae.txt' created successfully
#  File 'input/MSL_Note_c87b6bd4fcfc4f668bff9a42373fa807.txt' created successfully
#  File 'input/MSL_Note_625af5942ef9481283d2fd8a9b7c07c5.txt' created successfully
#  File 'input/MSL_Note_db0921aab1bf4f60bfbff194a6a592ab.txt' created successfully
#  File 'input/MSL_Note_40219ec51d1a4cd7baef4558c8a30e94.txt' created successfully
#  File 'input/MSL_Note_022bcc191eb34fbb89acd45b824f2849.txt' created successfully
#  File 'input/MSL_Note_b04b22a308f24ba3b761d41e035776f9.txt' created successfully
#  File 'input/MSL_Note_bd09514233284effbd2243b54520ce36.txt' created successfully
#  File 'input/MSL_Note_d511ed792669406186c29bd16dbde9f5.txt' created successfully
#  File 'input/MSL_Note_2a7a0524ea7946e293bb3757aa1b770a.txt' created successfully
#  File 'input/MSL_Note_64c2d11bff384bfa9b1eab3b4190539b.txt' created successfully
#  File 'input/MSL_Note_9440c1f60b4a4aca96ba9da3655c6ab1.txt' created successfully
#  File 'input/MSL_Note_2255b330272346bea4fe703448888cac.txt' created successfully
#  File 'input/MSL_Note_ebc74ca17b5a443697a17807df9b82f2.txt' created successfully
#  File 'input/MSL_Note_65de69215324499595aca1b19e9a6578.txt' created successfully
#  File 'input/MSL_Note_eca5ebc0ffd84ab9a40e6a3182cc5bdd.txt' created successfully
#  File 'input/MSL_Note_f6eecccb05de47af831057fa00e0dbb6.txt' created successfully
#  File 'input/MSL_Note_9cf1058419f74b8ca4c5ffc0e3422cae.txt' created successfully
#  File 'input/MSL_Note_af0a0b31631a4fcb8b7882b99850027f.txt' created successfully
#  File 'input/MSL_Note_922127beef3c4a34a64a6f1d3be0bb1c.txt' created successfully
#  File 'input/MSL_Note_7d005eaea6204681bd4882d0ae62cbfd.txt' created successfully
#  File 'input/MSL_Note_7119ac96ff834759b7c762adb37e33f7.txt' created successfully
#  File 'input/MSL_Note_1f40edf54b584e0aa803709f143395e0.txt' created successfully
#  File 'input/MSL_Note_aa7a096a31b7429ab83e289c2af692b6.txt' created successfully
#  File 'input/MSL_Note_8785eeb9eb9644bfaa5ab38b43199c46.txt' created successfully
#  File 'input/MSL_Note_fd6b50d19a5746f193d8faa4b0287daa.txt' created successfully
#  File 'input/MSL_Note_6dff76a374624d0abd80cb213ac7b46c.txt' created successfully
#  File 'input/MSL_Note_cc024b5370024d0b81cf6c930259994f.txt' created successfully
#  File 'input/MSL_Note_03cfbfc9483e4907a531e89db87616b9.txt' created successfully
#  File 'input/MSL_Note_a077a94a14ee4140a2b2ea08c969cb54.txt' created successfully
#  File 'input/MSL_Note_8411b55d11e34b89bcb110ba3b0968ca.txt' created successfully
#  File 'input/MSL_Note_aaf65408b57e435eb7252d27dbde0d1c.txt' created successfully
#  File 'input/MSL_Note_0b3ed494a9f141d5b6c6303f284721e8.txt' created successfully
#  File 'input/MSL_Note_79b18f9a8e7740b78b95afd1e8e3980b.txt' created successfully
#  File 'input/MSL_Note_3eab6574a0d84767ae665c012fb1ae61.txt' created successfully
#  File 'input/MSL_Note_71c1d59d62f945dd9232e5e18e244ed9.txt' created successfully
#  File 'input/MSL_Note_3b7f1eea1a52449b9459291d578ab143.txt' created successfully
#  File 'input/MSL_Note_956f98edbc0d4140b6ed532bfdfda1e8.txt' created successfully
#  File 'input/MSL_Note_f15c8c5a2b5c470e8c46f88dafa31c33.txt' created successfully
#  File 'input/MSL_Note_f9dd83ebd3cd45beb83e38ecf50d0eaf.txt' created successfully
#  File 'input/MSL_Note_83412df3735e45da8f927dfe295c2a43.txt' created successfully
#  File 'input/MSL_Note_fa2046d65cde41f0aa847c235f6899a9.txt' created successfully
#  File 'input/MSL_Note_1079d065d79f4cc7a9b02cca4628b112.txt' created successfully
#  File 'input/MSL_Note_f27217503f884013932aa816aa3fb8e2.txt' created successfully
#  File 'input/MSL_Note_ec4d96347f3f49e88adaf5d03de9c029.txt' created successfully
#  File 'input/MSL_Note_1980f5d698b542ee9671fd9964220f38.txt' created successfully
#  File 'input/MSL_Note_e9fa45f4623f49b6970707c406a2af5f.txt' created successfully
#  File 'input/MSL_Note_f723842a02a24f71926e4a0d5a150a0e.txt' created successfully
#  File 'input/MSL_Note_f35572b020e84d33864cb8a1e26808b8.txt' created successfully
#  File 'input/MSL_Note_ccbfa64091f849b598915f08121b0c17.txt' created successfully
#  File 'input/MSL_Note_04c4fb9d5e9440a2b3269222445c7da8.txt' created successfully
#  File 'input/MSL_Note_4ca8df47510943fcb1bcb7c5b6208ac1.txt' created successfully
#  File 'input/MSL_Note_f451fcbe2c75498bacaeb7dfaa8a0b9d.txt' created successfully
#  File 'input/MSL_Note_0095997af557412ab201e6fb4317545b.txt' created successfully
#  File 'input/MSL_Note_fdf5c8b234bf408aba613ad5305a8188.txt' created successfully
#  File 'input/MSL_Note_dba1061cf22e4d85a6f9fbc6666d95b7.txt' created successfully
#  File 'input/MSL_Note_b9a4e07e7d664a93a7a9775aab71229b.txt' created successfully
#  File 'input/MSL_Note_b4bc957f8a3f469a855b5c5dece60a53.txt' created successfully
#  File 'input/MSL_Note_92fa57e437e941889f793ad0de3ad2b7.txt' created successfully
#  File 'input/MSL_Note_81362dba5f5d4ea3b0046dd05f08c604.txt' created successfully
#  File 'input/MSL_Note_a3958ef2f2bc434799baff0ccfb32301.txt' created successfully
#  File 'input/MSL_Note_f8220586b56c4ce7b3e41c2a0bfa68a9.txt' created successfully
#  File 'input/MSL_Note_52316bdbc9cb46c8bd2184e5bd784a66.txt' created successfully
#  File 'input/MSL_Note_1e2b40acc32648cdac71d9953671fa8f.txt' created successfully
#  File 'input/MSL_Note_05a36f4157ae44779e74bb6eb3fd02ea.txt' created successfully
#  File 'input/MSL_Note_2b1d6c56f7f24242a5b379fdef0114df.txt' created successfully
#  File 'input/MSL_Note_6f2dd811691f4abc98e2271862e5de13.txt' created successfully
#  File 'input/MSL_Note_afb9aa399a824d6e9793bd24dcfc7992.txt' created successfully
#  File 'input/MSL_Note_d3c9792fce3546aa80ffa4ccaa1ee7ab.txt' created successfully
#  File 'input/MSL_Note_948ea515bdd343e1812b7c43b04da1d9.txt' created successfully
#  File 'input/MSL_Note_f5de1a7d9b9f4d36ab470348ef01a6a8.txt' created successfully
#  File 'input/MSL_Note_970fb10f78d748d18a8571bc5540c5a6.txt' created successfully
#  File 'input/MSL_Note_ff9b7efae97142a2be4b24ccd870c216.txt' created successfully
#  File 'input/MSL_Note_bfb0c7c2730342eda10329ab2a9db1c6.txt' created successfully
#  File 'input/MSL_Note_fc4bce04f67c4b33ba21c5670a873a71.txt' created successfully
#  File 'input/MSL_Note_83da8427d31a4c11bed33429202d645c.txt' created successfully
#  File 'input/MSL_Note_3c49bcc556ac493e92e58df714057cc4.txt' created successfully
#  File 'input/MSL_Note_2a42cb5cc876495caca0085fdbea28aa.txt' created successfully

# %%
df_unique_updated

# %%
pip install tiktoken

# %%
import os
import yaml
import pandas as pd
import tiktoken
import asyncio
from rich import print
from graphrag.query.indexer_adapters import (
    read_indexer_entities,
    read_indexer_relationships,
    read_indexer_reports,
    read_indexer_text_units,
)
from graphrag.query.context_builder.entity_extraction import EntityVectorStoreKey
from graphrag.query.input.loaders.dfs import store_entity_semantic_embeddings
from graphrag.query.llm.oai.chat_openai import ChatOpenAI
from graphrag.query.llm.oai.embedding import OpenAIEmbedding
from graphrag.query.llm.oai.typing import OpenaiApiType
from graphrag.query.structured_search.local_search.mixed_context import LocalSearchMixedContext
from graphrag.query.structured_search.local_search.search import LocalSearch
from graphrag.query.question_gen.local_gen import LocalQuestionGen
from graphrag.vector_stores.lancedb import LanceDBVectorStore

def load_config(config_path="settings.yaml"):
    with open(config_path, "r") as file:
        config = yaml.safe_load(file)
    return config

# Access configuration
config = load_config()

# 1. Setup LLM
api_key = config['llm']['api_key']
llm_model = config['llm']['model']
api_base = config['llm']['api_base']
api_version = config['llm']['api_version']
embedding_model = config['embeddings']['llm']['model']
deployment_name = config['llm']['deployment_name']
llm = ChatOpenAI(api_key=api_key, api_base=api_base, api_version=api_version, model=llm_model, deployment_name=deployment_name, api_type=OpenaiApiType.AzureOpenAI, max_retries=20)
token_encoder = tiktoken.get_encoding("cl100k_base")
embedding_deployment_name = config['embeddings']['llm']['deployment_name']
text_embedder = OpenAIEmbedding(api_key=api_key, api_base=api_base, api_version=api_version, deployment_name=embedding_deployment_name, api_type=OpenaiApiType.AzureOpenAI, model=embedding_model, max_retries=20)

# 2. Load the Context
INPUT_DIR = "output"
ENTITY_TABLE = "create_final_nodes"
ENTITY_EMBEDDING_TABLE = "create_final_entities"
RELATIONSHIP_TABLE = "create_final_relationships"
COMMUNITY_REPORT_TABLE = "create_final_community_reports"
TEXT_UNIT_TABLE = "create_final_text_units"
LANCEDB_URI = f"{INPUT_DIR}/lancedb"
COMMUNITY_LEVEL = 0

entity_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_TABLE}.parquet")
print(entity_df.columns)
entity_embedding_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_EMBEDDING_TABLE}.parquet")
print(entity_embedding_df.columns)
entities = read_indexer_entities(entity_df, entity_embedding_df, COMMUNITY_LEVEL)

description_embedding_store = LanceDBVectorStore(collection_name="entity_description_embeddings")
description_embedding_store.connect(db_uri=LANCEDB_URI)
store_entity_semantic_embeddings(entities=entities, vectorstore=description_embedding_store)

relationship_df = pd.read_parquet(f"{INPUT_DIR}/{RELATIONSHIP_TABLE}.parquet")
print(relationship_df.columns)
relationships = read_indexer_relationships(relationship_df)

report_df = pd.read_parquet(f"{INPUT_DIR}/{COMMUNITY_REPORT_TABLE}.parquet")
reports = read_indexer_reports(report_df, entity_df, COMMUNITY_LEVEL)

text_unit_df = pd.read_parquet(f"{INPUT_DIR}/{TEXT_UNIT_TABLE}.parquet")
text_units = read_indexer_text_units(text_unit_df)

context_builder = LocalSearchMixedContext(
    community_reports=reports,
    text_units=text_units,
    entities=entities,
    relationships=relationships,
    entity_text_embeddings=description_embedding_store,
    embedding_vectorstore_key=EntityVectorStoreKey.ID,
    text_embedder=text_embedder,
    token_encoder=token_encoder,
)

# 4. Setup Local Search
local_context_params = { "text_unit_prop": 0.5, "community_prop": 0.1, "conversation_history_max_turns": 5, "conversation_history_user_turns_only": True, "top_k_mapped_entities": 10, "top_k_relationships": 10, "include_entity_rank": True, "include_relationship_weight": True, "include_community_rank": False, "return_candidate_context": False, "max_tokens": 12_000, }
llm_params = { "max_tokens": 2_000, "temperature": 0.0, }
search_engine = LocalSearch(
    llm=llm,
    context_builder=context_builder,
    token_encoder=token_encoder,
    llm_params=llm_params,
    context_builder_params=local_context_params,
    response_type="multiple paragraphs",
)
print("search engine: \n")
# print(search_engine.__dict__)
import pprint
pprint.pprint(vars(search_engine.context_builder))



# 5. Run Local Search
async def run_search(query: str):
    result = await search_engine.asearch(query)
    return result

if __name__ == "__main__":
    query = "Who is Twemlow?"
    result = await run_search(query)
    generated_response = result.response
    print("Response: \n",result.response)
    print("Entities: \n",result.context_data["entities"].head())
    print("Relationships: \n",result.context_data["relationships"].head())
    print("Reports: \n",result.context_data["reports"].head())
    sources = result.context_data["sources"]
    # print("Sources: \n",result.context_data["sources"])
    if "claims" in result.context_data:
        print(result.context_data["claims"].head())
# Out:
# Index(['id', 'human_readable_id', 'title', 'community', 'level', 'degree', 'x',
#        'y'],
#       dtype='object')
# Index(['id', 'human_readable_id', 'title', 'type', 'description',
#        'text_unit_ids'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/3r/nk0p7hl1449dqz5kz8_hd_700000gn/T/ipykernel_39660/3535755977.py in ?()
#      53 entity_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_TABLE}.parquet")
#      54 print(entity_df.columns)
#      55 entity_embedding_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_EMBEDDING_TABLE}.parquet")
#      56 print(entity_embedding_df.columns)
# ---> 57 entities = read_indexer_entities(entity_df, entity_embedding_df, COMMUNITY_LEVEL)
#      58
#      59 description_embedding_store = LanceDBVectorStore(collection_name="entity_description_embeddings")
#      60 description_embedding_store.connect(db_uri=LANCEDB_URI)
#
# ~/Desktop/GraphRAG_using_RAGAS/RAGAS_env/lib/python3.12/site-packages/graphrag/query/indexer_adapters.py in ?(final_nodes, final_entities, community_level)
#     109     entity_df = (
#     110         entity_df.groupby(["name", "rank"]).agg({"community": "max"}).reset_index()
#     111     )
#     112     entity_df["community"] = entity_df["community"].apply(lambda x: [str(x)])
# --> 113     entity_df = entity_df.merge(
#     114         entity_embedding_df, on="name", how="inner"
#     115     ).drop_duplicates(subset=["name"])
#     116
#
# ~/Desktop/GraphRAG_using_RAGAS/RAGAS_env/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10828         validate: MergeValidate | None = None,
#   10829     ) -> DataFrame:
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#   10835             how=how,
#
# ~/Desktop/GraphRAG_using_RAGAS/RAGAS_env/lib/python3.12/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# ~/Desktop/GraphRAG_using_RAGAS/RAGAS_env/lib/python3.12/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# ~/Desktop/GraphRAG_using_RAGAS/RAGAS_env/lib/python3.12/site-packages/pandas/core/reshape/merge.py in ?(self)
#    1293                         # Then we're either Hashable or a wrong-length arraylike,
#    1294                         #  the latter of which will raise
#    1295                         rk = cast(Hashable, rk)
#    1296                         if rk is not None:
# -> 1297                             right_keys.append(right._get_label_or_level_values(rk))
#    1298                         else:
#    1299                             # work-around for merge_asof(right_index=True)
#    1300                             right_keys.append(right.index._values)
#
# ~/Desktop/GraphRAG_using_RAGAS/RAGAS_env/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'name'

# %%
pip install graphrag==0.2.1

# %%
import graphrag.query.input.loaders.dfs as dfs
print(dir(dfs))
